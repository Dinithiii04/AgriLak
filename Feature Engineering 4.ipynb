# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset=pd.read_csv('/content/DSGP_Final_2.csv')
dataset.head()
# Out:
#          Date        T2M     T2MDEW         TS  T2M_RANGE    T2M_MAX  T2M_MIN  \
# 0  1990-01-01  25.438333  22.776667  25.558333   4.303333  27.983333   23.680
# 1  1990-01-11  24.637000  21.199000  24.792000   5.206000  27.725000   22.518
# 2  1990-01-21  24.559333  20.202667  24.854000   7.052667  28.532000   21.480
# 3  1990-02-01  25.503333  20.528333  26.280000   7.721667  29.900000   22.180
# 4  1990-02-11  27.009000  22.133000  27.867000   6.830000  30.994000   24.167
#
#         QV2M       RH2M          PS      WS2M  WS2M_MAX  WS2M_MIN   GWETTOP  \
# 0  17.335000  85.625000  100.558333  3.731667  5.241667  2.311667  0.646667
# 1  15.753000  81.599000  100.673000  2.985000  4.245000  2.019000  0.714000
# 2  14.798667  77.519333  100.670000  2.586667  3.802667  1.584667  0.586000
# 3  15.055000  75.051667  100.713333  3.031667  4.255000  1.913333  0.503333
# 4  16.651000  75.986000  100.651000  3.634000  4.939000  2.305000  0.456000
#
# ...

# %%
dataset['1_month_rainfall_aggregate'].hist( bins=30)  # Call the hist() method to generate the histogram
plt.xlabel('Rainfall')
plt.ylabel('Frequency')
plt.title('Histogram of Rainfall')
plt.show()

# %%
sns.histplot(x=dataset['1_month_rainfall_aggregate'])
plt.show()

# %%
sns.pairplot(dataset)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sns.histplot(dataset)
plt.show()

# %%
dataset.hist(bins=50, figsize=(15, 20), edgecolor='black', linewidth=1.2)
plt.show()
